# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image

# Define the CNN model
model = tf.keras.Sequential([
    layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(256, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Load the dataset
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')

X_train = np.array(train.iloc[:, 1:])
y_train = np.array(train.iloc[:, 0])

X_test = np.array(test.iloc[:, 1:])
y_test = np.array(test.iloc[:, 0])

# Reshape the input data
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Convert the labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Train the model
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy:', test_acc)

# %% [markdown]
# increase no of epochs

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image

model = tf.keras.Sequential([
    layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(256, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Load the dataset
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')

X_train = np.array(train.iloc[:, 1:])
y_train = np.array(train.iloc[:, 0])

X_test = np.array(test.iloc[:, 1:])
y_test = np.array(test.iloc[:, 0])

# Reshape the input data
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Convert the labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Train the model
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 858/858 [==============================] - 101s 115ms/step - loss: 2.6013 - accuracy: 0.2480 - val_loss: 1.0926 - val_accuracy: 0.6687
# Epoch 2/50
# 858/858 [==============================] - 99s 116ms/step - loss: 0.6885 - accuracy: 0.7712 - val_loss: 0.2280 - val_accuracy: 0.9322
# Epoch 3/50
# 858/858 [==============================] - 96s 111ms/step - loss: 0.2520 - accuracy: 0.9197 - val_loss: 0.1869 - val_accuracy: 0.9437
# Epoch 4/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1895 - accuracy: 0.9429 - val_loss: 0.2292 - val_accuracy: 0.9294
# Epoch 5/50
# 858/858 [==============================] - 95s 111ms/step - loss: 0.1393 - accuracy: 0.9605 - val_loss: 0.2444 - val_accuracy: 0.9384
# Epoch 6/50
# 858/858 [==============================] - 102s 119ms/step - loss: 0.1503 - accuracy: 0.9597 - val_loss: 0.2536 - val_accuracy: 0.9180
# Epoch 7/50
# 858/858 [==============================] - 95s 111ms/step - loss: 0.1370 - accuracy: 0.9632 - val_loss: 0.3358 - val_accuracy: 0.9370
# Epoch 8/50
# 858/858 [==============================] - 98s 115ms/step - loss: 0.1302 - accuracy: 0.9675 - val_loss: 0.2905 - val_accuracy: 0.9483
# Epoch 9/50
# 858/858 [==============================] - 96s 111ms/step - loss: 0.1434 - accuracy: 0.9665 - val_loss: 0.2352 - val_accuracy: 0.9504
# Epoch 10/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1245 - accuracy: 0.9700 - val_loss: 0.2356 - val_accuracy: 0.9519
# Epoch 11/50
# 858/858 [==============================] - 95s 110ms/step - loss: 0.1262 - accuracy: 0.9705 - val_loss: 0.2446 - val_accuracy: 0.9481
# Epoch 12/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1349 - accuracy: 0.9712 - val_loss: 0.3139 - val_accuracy: 0.9530
# Epoch 13/50
# 858/858 [==============================] - 101s 118ms/step - loss: 0.1390 - accuracy: 0.9710 - val_loss: 0.4927 - val_accuracy: 0.9559
# Epoch 14/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1471 - accuracy: 0.9714 - val_loss: 0.2887 - val_accuracy: 0.9452
# Epoch 15/50
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1468 - accuracy: 0.9720 - val_loss: 0.3869 - val_accuracy: 0.9321
# Epoch 16/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1412 - accuracy: 0.9736 - val_loss: 0.3929 - val_accuracy: 0.9396
# Epoch 17/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1184 - accuracy: 0.9770 - val_loss: 0.5050 - val_accuracy: 0.9378
# Epoch 18/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1714 - accuracy: 0.9699 - val_loss: 0.3053 - val_accuracy: 0.9458
# Epoch 19/50
# 858/858 [==============================] - 102s 119ms/step - loss: 0.1604 - accuracy: 0.9720 - val_loss: 0.6915 - val_accuracy: 0.9102
# Epoch 20/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1465 - accuracy: 0.9759 - val_loss: 0.4540 - val_accuracy: 0.9548
# Epoch 21/50
# 858/858 [==============================] - 96s 111ms/step - loss: 0.1579 - accuracy: 0.9739 - val_loss: 0.4331 - val_accuracy: 0.9479
# Epoch 22/50
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1778 - accuracy: 0.9766 - val_loss: 0.5179 - val_accuracy: 0.9445
# Epoch 23/50
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1713 - accuracy: 0.9776 - val_loss: 0.4522 - val_accuracy: 0.9444
# Epoch 24/50
# 858/858 [==============================] - 97s 114ms/step - loss: 0.1487 - accuracy: 0.9772 - val_loss: 0.5957 - val_accuracy: 0.9487
# Epoch 25/50
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1619 - accuracy: 0.9787 - val_loss: 0.5564 - val_accuracy: 0.9451
# Epoch 26/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.2079 - accuracy: 0.9750 - val_loss: 0.5612 - val_accuracy: 0.9477
# Epoch 27/50
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1614 - accuracy: 0.9789 - val_loss: 0.7123 - val_accuracy: 0.9545
# Epoch 28/50
# 858/858 [==============================] - 99s 116ms/step - loss: 0.1977 - accuracy: 0.9765 - val_loss: 0.3725 - val_accuracy: 0.9430
# Epoch 29/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1822 - accuracy: 0.9777 - val_loss: 0.6801 - val_accuracy: 0.9363
# Epoch 30/50
# 858/858 [==============================] - 102s 118ms/step - loss: 0.1644 - accuracy: 0.9812 - val_loss: 1.1543 - val_accuracy: 0.9417
# Epoch 31/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.1841 - accuracy: 0.9769 - val_loss: 0.6295 - val_accuracy: 0.9516
# Epoch 32/50
# 858/858 [==============================] - 100s 117ms/step - loss: 0.1937 - accuracy: 0.9785 - val_loss: 0.5312 - val_accuracy: 0.9643
# Epoch 33/50
# 858/858 [==============================] - 99s 116ms/step - loss: 0.1986 - accuracy: 0.9777 - val_loss: 1.0913 - val_accuracy: 0.9329
# Epoch 34/50
# 858/858 [==============================] - 99s 116ms/step - loss: 0.1731 - accuracy: 0.9801 - val_loss: 0.5509 - val_accuracy: 0.9445
# Epoch 35/50
# 858/858 [==============================] - 98s 115ms/step - loss: 0.2107 - accuracy: 0.9771 - val_loss: 0.2724 - val_accuracy: 0.9649
# Epoch 36/50
# 858/858 [==============================] - 101s 117ms/step - loss: 0.1709 - accuracy: 0.9813 - val_loss: 0.5608 - val_accuracy: 0.9410
# Epoch 37/50
# 858/858 [==============================] - 99s 116ms/step - loss: 0.1416 - accuracy: 0.9853 - val_loss: 0.8108 - val_accuracy: 0.9614
# Epoch 38/50
# 858/858 [==============================] - 97s 114ms/step - loss: 0.2410 - accuracy: 0.9761 - val_loss: 1.1282 - val_accuracy: 0.9434
# Epoch 39/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.2402 - accuracy: 0.9781 - val_loss: 0.4794 - val_accuracy: 0.9576
# Epoch 40/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1718 - accuracy: 0.9819 - val_loss: 0.8743 - val_accuracy: 0.9339
# Epoch 41/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.2070 - accuracy: 0.9781 - val_loss: 0.5237 - val_accuracy: 0.9522
# Epoch 42/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.1773 - accuracy: 0.9792 - val_loss: 0.8726 - val_accuracy: 0.9444
# Epoch 43/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.1752 - accuracy: 0.9810 - val_loss: 0.5872 - val_accuracy: 0.9430
# Epoch 44/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.2603 - accuracy: 0.9763 - val_loss: 0.9482 - val_accuracy: 0.9081
# Epoch 45/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.2116 - accuracy: 0.9801 - val_loss: 0.5765 - val_accuracy: 0.9575
# Epoch 46/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.2425 - accuracy: 0.9801 - val_loss: 1.1204 - val_accuracy: 0.9416
# Epoch 47/50
# 858/858 [==============================] - 98s 115ms/step - loss: 0.2289 - accuracy: 0.9827 - val_loss: 0.7834 - val_accuracy: 0.9558
# Epoch 48/50
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1802 - accuracy: 0.9850 - val_loss: 1.0964 - val_accuracy: 0.9575
# Epoch 49/50
# 858/858 [==============================] - 98s 114ms/step - loss: 0.2571 - accuracy: 0.9792 - val_loss: 0.6660 - val_accuracy: 0.9608
# Epoch 50/50
# 858/858 [==============================] - 99s 115ms/step - loss: 0.1845 - accuracy: 0.9841 - val_loss: 0.7765 - val_accuracy: 0.9502
# 225/225 [==============================] - 5s 23ms/step - loss: 0.7765 - accuracy: 0.9502
# Test accuracy: 0.9502230882644653

# %% [markdown]
# change optimiser

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image

model = tf.keras.Sequential([
    layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(256, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Load the dataset
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')

X_train = np.array(train.iloc[:, 1:])
y_train = np.array(train.iloc[:, 0])

X_test = np.array(test.iloc[:, 1:])
y_test = np.array(test.iloc[:, 0])

# Reshape the input data
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Convert the labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Train the model
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy:', test_acc)
# Out:
# Epoch 1/20
# 858/858 [==============================] - 99s 114ms/step - loss: 3.2237 - accuracy: 0.1003 - val_loss: 2.6212 - val_accuracy: 0.2288
# Epoch 2/20
# 858/858 [==============================] - 97s 114ms/step - loss: 2.3835 - accuracy: 0.2691 - val_loss: 1.9376 - val_accuracy: 0.4578
# Epoch 3/20
# 858/858 [==============================] - 98s 114ms/step - loss: 1.9056 - accuracy: 0.4056 - val_loss: 1.5527 - val_accuracy: 0.5487
# Epoch 4/20
# 858/858 [==============================] - 98s 114ms/step - loss: 1.5166 - accuracy: 0.5203 - val_loss: 1.0328 - val_accuracy: 0.6873
# Epoch 5/20
# 858/858 [==============================] - 107s 125ms/step - loss: 1.1378 - accuracy: 0.6336 - val_loss: 0.7564 - val_accuracy: 0.7978
# Epoch 6/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.8589 - accuracy: 0.7159 - val_loss: 0.5693 - val_accuracy: 0.8306
# Epoch 7/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.7047 - accuracy: 0.7671 - val_loss: 0.9867 - val_accuracy: 0.7253
# Epoch 8/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.6036 - accuracy: 0.8031 - val_loss: 0.3787 - val_accuracy: 0.8854
# Epoch 9/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.4912 - accuracy: 0.8388 - val_loss: 0.3148 - val_accuracy: 0.9134
# Epoch 10/20
# 858/858 [==============================] - 98s 115ms/step - loss: 0.4206 - accuracy: 0.8637 - val_loss: 0.2847 - val_accuracy: 0.9215
# Epoch 11/20
# 858/858 [==============================] - 98s 115ms/step - loss: 0.3681 - accuracy: 0.8813 - val_loss: 0.3745 - val_accuracy: 0.9062
# Epoch 12/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.3164 - accuracy: 0.8975 - val_loss: 0.2821 - val_accuracy: 0.9136
# Epoch 13/20
# 858/858 [==============================] - 98s 114ms/step - loss: 0.2722 - accuracy: 0.9141 - val_loss: 0.2521 - val_accuracy: 0.9320
# Epoch 14/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.2427 - accuracy: 0.9245 - val_loss: 0.2356 - val_accuracy: 0.9260
# Epoch 15/20
# 858/858 [==============================] - 98s 114ms/step - loss: 0.2302 - accuracy: 0.9277 - val_loss: 0.2453 - val_accuracy: 0.9313
# Epoch 16/20
# 858/858 [==============================] - 98s 115ms/step - loss: 0.2069 - accuracy: 0.9356 - val_loss: 0.2150 - val_accuracy: 0.9400
# Epoch 17/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1863 - accuracy: 0.9428 - val_loss: 0.1831 - val_accuracy: 0.9387
# Epoch 18/20
# 858/858 [==============================] - 102s 119ms/step - loss: 0.1851 - accuracy: 0.9431 - val_loss: 0.2322 - val_accuracy: 0.9374
# Epoch 19/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.1684 - accuracy: 0.9477 - val_loss: 0.1987 - val_accuracy: 0.9318
# Epoch 20/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1571 - accuracy: 0.9513 - val_loss: 0.1976 - val_accuracy: 0.9322
# 225/225 [==============================] - 6s 26ms/step - loss: 0.1976 - accuracy: 0.9322
# Test accuracy: 0.9322364926338196

# %% [markdown]
# remove convolutional layer

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image

model = tf.keras.Sequential([
    layers.Conv2D(128, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Conv2D(256, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Load the dataset
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')

X_train = np.array(train.iloc[:, 1:])
y_train = np.array(train.iloc[:, 0])

X_test = np.array(test.iloc[:, 1:])
y_test = np.array(test.iloc[:, 0])

# Reshape the input data
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Convert the labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Train the model
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy:', test_acc)
# Out:
# Epoch 1/20
# 858/858 [==============================] - 86s 98ms/step - loss: 2.1860 - accuracy: 0.5167 - val_loss: 0.5141 - val_accuracy: 0.8334
# Epoch 2/20
# 858/858 [==============================] - 80s 94ms/step - loss: 0.2852 - accuracy: 0.9078 - val_loss: 0.2996 - val_accuracy: 0.9184
# Epoch 3/20
# 858/858 [==============================] - 80s 94ms/step - loss: 0.1244 - accuracy: 0.9607 - val_loss: 0.2718 - val_accuracy: 0.9222
# Epoch 4/20
# 858/858 [==============================] - 86s 100ms/step - loss: 0.1292 - accuracy: 0.9635 - val_loss: 0.3692 - val_accuracy: 0.9049
# Epoch 5/20
# 858/858 [==============================] - 95s 111ms/step - loss: 0.1112 - accuracy: 0.9701 - val_loss: 0.2906 - val_accuracy: 0.9470
# Epoch 6/20
# 858/858 [==============================] - 97s 113ms/step - loss: 0.1017 - accuracy: 0.9749 - val_loss: 0.2642 - val_accuracy: 0.9488
# Epoch 7/20
# 858/858 [==============================] - 101s 118ms/step - loss: 0.0922 - accuracy: 0.9785 - val_loss: 0.4073 - val_accuracy: 0.9275
# Epoch 8/20
# 858/858 [==============================] - 109s 127ms/step - loss: 0.1033 - accuracy: 0.9769 - val_loss: 0.3842 - val_accuracy: 0.9470
# Epoch 9/20
# 858/858 [==============================] - 102s 118ms/step - loss: 0.1016 - accuracy: 0.9773 - val_loss: 0.4312 - val_accuracy: 0.9377
# Epoch 10/20
# 858/858 [==============================] - 100s 117ms/step - loss: 0.0877 - accuracy: 0.9814 - val_loss: 0.4606 - val_accuracy: 0.9317
# Epoch 11/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.0830 - accuracy: 0.9835 - val_loss: 0.5399 - val_accuracy: 0.9459
# Epoch 12/20
# 858/858 [==============================] - 101s 118ms/step - loss: 0.1307 - accuracy: 0.9794 - val_loss: 0.6253 - val_accuracy: 0.9335
# Epoch 13/20
# 858/858 [==============================] - 95s 111ms/step - loss: 0.1242 - accuracy: 0.9804 - val_loss: 0.5357 - val_accuracy: 0.9428
# Epoch 14/20
# 858/858 [==============================] - 100s 117ms/step - loss: 0.0971 - accuracy: 0.9853 - val_loss: 0.6690 - val_accuracy: 0.9335
# Epoch 15/20
# 858/858 [==============================] - 96s 112ms/step - loss: 0.0858 - accuracy: 0.9867 - val_loss: 0.9426 - val_accuracy: 0.9396
# Epoch 16/20
# 858/858 [==============================] - 86s 100ms/step - loss: 0.1359 - accuracy: 0.9831 - val_loss: 0.8407 - val_accuracy: 0.9446
# Epoch 17/20
# 858/858 [==============================] - 83s 97ms/step - loss: 0.1336 - accuracy: 0.9843 - val_loss: 0.9885 - val_accuracy: 0.9424
# Epoch 18/20
# 858/858 [==============================] - 83s 97ms/step - loss: 0.0895 - accuracy: 0.9895 - val_loss: 1.0760 - val_accuracy: 0.9502
# Epoch 19/20
# 858/858 [==============================] - 84s 98ms/step - loss: 0.1396 - accuracy: 0.9861 - val_loss: 1.2615 - val_accuracy: 0.9481
# Epoch 20/20
# 858/858 [==============================] - 86s 100ms/step - loss: 0.1500 - accuracy: 0.9867 - val_loss: 0.9501 - val_accuracy: 0.9538
# 225/225 [==============================] - 5s 24ms/step - loss: 0.9501 - accuracy: 0.9538
# Test accuracy: 0.9538483023643494
